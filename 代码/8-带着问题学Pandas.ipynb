# %% [markdown]
# ## <font color='red'>高中体测字符串类型数据如何转换？（项目实战）</font>

# %% [markdown]
# ### replace知识点

# %%
s1 = '我大学体能极限是1000米3分34秒！'
# 将我字替换为："派"。
# replace()函数中第一个是替换前的，第二个替换后的
s1 = s1.replace('我', 'MathDance')
print(s1)

# 将成绩转化为纯数字
s2 = "4'04" # 字符串
# s2 = s2.replace("'", '.')
s2 = s2.replace('\'', '.')
s2 = float(s2) # 数据类型转换
print(s2)
# Out:
# MathDance大学体能极限是1000米3分34秒！
# 4.04

# %% [markdown]
# ### 常见报错演示

# %%
score = ["4'03", "4'34", "4'29", "3'48", "3'58",4]
# for循环批量替换
for s in score:
    s = s.replace('\'', '.')
    print(s)
# Out:
# 4.03
# 4.34
# 4.29
# 3.48
# 3.58
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 3>()
#       2 # for循环批量替换
#       3 for s in score:
# ----> 4     s = s.replace('\'', '.')
#       5     print(s)
#
# AttributeError: 'int' object has no attribute 'replace'

# %% [markdown]
# ### 报错debug

# %%
score = ["4'03", "4'34", "4'29", "3'48", "3'58",4]
# for循环批量替换
for s in score:
    if isinstance(s,str):
        s = s.replace('\'', '.')
    print(s)
# Out:
# 4.03
# 4.34
# 4.29
# 3.48
# 3.58
# 4

# %% [markdown]
# ### 男生1000米跑成绩数据处理

# %%
import pandas as pd
pd.read_excel('./项目实战一（体测数据处理）/体测成绩.xlsx',sheet_name='男生')
# Out:
#      性别     姓名 男1000米跑  男50米跑    男跳远  男体前屈   男引体    男肺活量
# 0     男  郭*森18    5'19   9.55  210.0  15.0   6.0  7042.0
# 1     男  苏*飞27    4'12   8.60  215.0  15.0  11.0  3458.0
# 2     男  寻*潇13    4'17   8.16  215.0  14.0   4.0  4336.0
# 3     男  郭*冉36    4'19   8.96  205.0  14.0   0.0  4539.0
# 4     男  王*磊40     NaN   8.30  230.0  14.0   9.0  6059.0
# ...  ..    ...     ...    ...    ...   ...   ...     ...
# 1080  男   闫*轩1    4'04   8.13  210.0   1.0   7.0  5012.0
# 1081  男   王*飞2    3'49   7.62  203.0  11.0  12.0  4138.0
# 1082  男   赵*龙1    5'02   9.50  200.0  14.0   5.0  1437.0
# 1083  男  毕*谦28    4'26   8.52  210.0  18.0   9.0  4814.0
# 1084  男  李*阳19     4'2   8.21  219.0   6.0  10.0  4469.0
#
# [1085 rows x 8 columns]

# %%
import pandas as pd
# 加载男生的体测成绩
df_boy = pd.read_excel('./项目实战一（体测数据处理）/体测成绩.xlsx',sheet_name = 0)
# 空数据处理：没有参加体能测试，成绩为0
df_boy = df_boy.fillna(0)
def convert(s):
    if isinstance(s, str):
        s = float(s.replace('\'', '.'))
    return s
df_boy['男1000米跑'] = df_boy['男1000米跑'].map(convert)
df_boy.to_excel('./项目实战一（体测数据处理）/体测成绩_男.xlsx',index = False)

# %% [markdown]
# ### 女生800米跑成绩数据处理

# %%
pd.read_excel('./项目实战一（体测数据处理）/体测成绩.xlsx',sheet_name='女生')
# Out:
#      性别     姓名 女800米跑  女50米跑  女跳远  女体前屈  女仰卧  女肺活量
# 0     女   李*帆6      4   9.92  172    23   40  2348
# 1     女  吕*璇40   3'55  10.94  160    14   39  2588
# 2     女  任*哲30   3'29   8.79  150    17   36  3043
# 3     女  李*琦13   3'36  10.16  167    13   41  3276
# 4     女  高*润32   3'49   9.99  160    10   40  2410
# ...  ..    ...    ...    ...  ...   ...  ...   ...
# 1069  女  贾*华35   3'52   9.84  178    18   40  2350
# 1070  女  井*欣15   4'08   9.80  165    15   40  4086
# 1071  女  王*辉28   3'58   9.60  160    30   40  3059
# 1072  女  陈*怡30   3'32  10.08  152    19   39  2982
# 1073  女  麻*蕾29   3'45   9.05  152    18   40  3122
#
# [1074 rows x 8 columns]

# %%
import pandas as pd
# 加载女生的体测成绩
df_girl = pd.read_excel('./项目实战一（体测数据处理）/体测成绩.xlsx',sheet_name =1)
# 空数据处理：没有参加体能测试，成绩为0
df_girl = df_girl.fillna(0)
def convert(s):
    if isinstance(s, str):
        s = float(s.replace('\'', '.'))
    return s
df_girl['女800米跑'] = df_girl['女800米跑'].map(convert)
df_girl.to_excel('./项目实战一（体测数据处理）/体测成绩_女.xlsx',index = False)
df_girl
# Out:
#      性别     姓名  女800米跑  女50米跑  女跳远  女体前屈  女仰卧  女肺活量
# 0     女   李*帆6    4.00   9.92  172    23   40  2348
# 1     女  吕*璇40    3.55  10.94  160    14   39  2588
# 2     女  任*哲30    3.29   8.79  150    17   36  3043
# 3     女  李*琦13    3.36  10.16  167    13   41  3276
# 4     女  高*润32    3.49   9.99  160    10   40  2410
# ...  ..    ...     ...    ...  ...   ...  ...   ...
# 1069  女  贾*华35    3.52   9.84  178    18   40  2350
# 1070  女  井*欣15    4.08   9.80  165    15   40  4086
# 1071  女  王*辉28    3.58   9.60  160    30   40  3059
# 1072  女  陈*怡30    3.32  10.08  152    19   39  2982
# 1073  女  麻*蕾29    3.45   9.05  152    18   40  3122
#
# [1074 rows x 8 columns]

# %% [markdown]
# ## <font color='red'>高中体测评分表数据转换？（项目实战）</font>

# %% [markdown]
# ### 男生1000米跑成绩数据处理（方式二）

# %%
import pandas as pd
# 加载男生的体测成绩
df_boy = pd.read_excel('./项目实战一（体测数据处理）/体测成绩.xlsx',sheet_name = 0)
# 空数据处理：没有参加体能测试，成绩为0
df_boy['男1000米跑'].str.replace('\'','.').fillna(0).astype(np.float64)
# Out:
# 0       5.19
# 1       4.12
# 2       4.17
# 3       4.19
# 4       0.00
#         ...
# 1080    4.04
# 1081    3.49
# 1082    5.02
# 1083    4.26
# 1084    4.20
# Name: 男1000米跑, Length: 1085, dtype: float64

# %%
pd.Series.str.split()

# %% [markdown]
# ### 体测成绩评分表数据转换

# %%
import numpy as np
import pandas as pd
# 评分标准，多层索引
# header:告诉pandas 第一行和第二行作为列索引
score = pd.read_excel('./项目实战一（体测数据处理）/体侧成绩评分表.xls',header=[0,1])
display(score)
# Out:
#     男肺活量       女肺活量      男50米跑      女50米跑       男体前屈       ...  女跳远       \
#       成绩   分数    成绩   分数    成绩   分数    成绩   分数    成绩   分数  ...   成绩   分数
# 0   4540  100  3150  100   7.1  100   7.8  100  23.6  100  ...  204  100
# 1   4420   95  3100   95   7.2   95   7.9   95  21.5   95  ...  198   95
# 2   4300   90  3050   90   7.3   90   8.0   90  19.4   90  ...  192   90
# 3   4050   85  2900   85   7.4   85   8.3   85  17.2   85  ...  185   85
# 4   3800   80  2750   80   7.5   80   8.6   80  15.0   80  ...  178   80
# 5   3680   78  2650   78   7.7   78   8.8   78  13.6   78  ...  175   78
# 6   3560   76  2550   76   7.9   76   9.0   76  12.2   76  ...  172   76
# 7   3440   74  2450   74   8.1   74   9.2   74  10.8   74  ...  169   74
# 8   3320   72  2350   72   8.3   72   9.4   72   9.4   72  ...  166   72
# 9   3200   70  2250   70   8.5   70   9.6   70   8.0   70  ...  163   70
# 10  3080   68  2150   68   8.7   68   9.8   68   6.6   68  ...  160   68
# ...

# %%
score.iloc[:,-4]
# Out:
# 0     3'30"
# 1     3'35"
# 2     3'40"
# 3     3'47"
# 4     3'55"
# 5     4'00"
# 6     4'05"
# 7     4'10"
# 8     4'15"
# 9     4'20"
# 10    4'25"
# 11    4'30"
# 12    4'35"
# 13    4'40"
# 14    4'45"
# 15    5'05"
# 16    5'25"
# 17    5'45"
# 18    6'05"
# 19    6'25"
# Name: (男1000米跑, 成绩), dtype: object

# %%
# 男生考核标准转换
score.iloc[:,-4] = score.iloc[:,-4].str.replace('\'','.').str.strip('"')
# 女生考核标准准换
score.iloc[:,-2] = score.iloc[:,-2].str.replace('\'','.').str.strip('"')
display(score,score.dtypes)
# Out:
#     男肺活量       女肺活量      男50米跑      女50米跑       男体前屈       ...  女跳远       \
#       成绩   分数    成绩   分数    成绩   分数    成绩   分数    成绩   分数  ...   成绩   分数
# 0   4540  100  3150  100   7.1  100   7.8  100  23.6  100  ...  204  100
# 1   4420   95  3100   95   7.2   95   7.9   95  21.5   95  ...  198   95
# 2   4300   90  3050   90   7.3   90   8.0   90  19.4   90  ...  192   90
# 3   4050   85  2900   85   7.4   85   8.3   85  17.2   85  ...  185   85
# 4   3800   80  2750   80   7.5   80   8.6   80  15.0   80  ...  178   80
# 5   3680   78  2650   78   7.7   78   8.8   78  13.6   78  ...  175   78
# 6   3560   76  2550   76   7.9   76   9.0   76  12.2   76  ...  172   76
# 7   3440   74  2450   74   8.1   74   9.2   74  10.8   74  ...  169   74
# 8   3320   72  2350   72   8.3   72   9.4   72   9.4   72  ...  166   72
# 9   3200   70  2250   70   8.5   70   9.6   70   8.0   70  ...  163   70
# 10  3080   68  2150   68   8.7   68   9.8   68   6.6   68  ...  160   68
# ...

# %%
# -------数据类型转换-------
score[('男1000米跑','成绩')] = score[('男1000米跑','成绩')].astype(np.float64)
score[('女800米跑','成绩')] = score[('女800米跑','成绩')].astype(np.float64)
display(score,score.dtypes)
# Out:
#     男肺活量       女肺活量      男50米跑      女50米跑       男体前屈       ...  女跳远       \
#       成绩   分数    成绩   分数    成绩   分数    成绩   分数    成绩   分数  ...   成绩   分数
# 0   4540  100  3150  100   7.1  100   7.8  100  23.6  100  ...  204  100
# 1   4420   95  3100   95   7.2   95   7.9   95  21.5   95  ...  198   95
# 2   4300   90  3050   90   7.3   90   8.0   90  19.4   90  ...  192   90
# 3   4050   85  2900   85   7.4   85   8.3   85  17.2   85  ...  185   85
# 4   3800   80  2750   80   7.5   80   8.6   80  15.0   80  ...  178   80
# 5   3680   78  2650   78   7.7   78   8.8   78  13.6   78  ...  175   78
# 6   3560   76  2550   76   7.9   76   9.0   76  12.2   76  ...  172   76
# 7   3440   74  2450   74   8.1   74   9.2   74  10.8   74  ...  169   74
# 8   3320   72  2350   72   8.3   72   9.4   72   9.4   72  ...  166   72
# 9   3200   70  2250   70   8.5   70   9.6   70   8.0   70  ...  163   70
# 10  3080   68  2150   68   8.7   68   9.8   68   6.6   68  ...  160   68
# ...

# %%
# -------数据持久化保存-------
display(score)
score.to_excel('./项目实战一（体测数据处理）/体侧成绩评分表_处理.xlsx',header=[0,1])
# Out:
#     男肺活量       女肺活量      男50米跑      女50米跑       男体前屈       ...  女跳远       \
#       成绩   分数    成绩   分数    成绩   分数    成绩   分数    成绩   分数  ...   成绩   分数
# 0   4540  100  3150  100   7.1  100   7.8  100  23.6  100  ...  204  100
# 1   4420   95  3100   95   7.2   95   7.9   95  21.5   95  ...  198   95
# 2   4300   90  3050   90   7.3   90   8.0   90  19.4   90  ...  192   90
# 3   4050   85  2900   85   7.4   85   8.3   85  17.2   85  ...  185   85
# 4   3800   80  2750   80   7.5   80   8.6   80  15.0   80  ...  178   80
# 5   3680   78  2650   78   7.7   78   8.8   78  13.6   78  ...  175   78
# 6   3560   76  2550   76   7.9   76   9.0   76  12.2   76  ...  172   76
# 7   3440   74  2450   74   8.1   74   9.2   74  10.8   74  ...  169   74
# 8   3320   72  2350   72   8.3   72   9.4   72   9.4   72  ...  166   72
# 9   3200   70  2250   70   8.5   70   9.6   70   8.0   70  ...  163   70
# 10  3080   68  2150   68   8.7   68   9.8   68   6.6   68  ...  160   68
# ...

# %%
pd.read_excel('./项目实战一（体测数据处理）/体侧成绩评分表_处理.xlsx',header=[0,1],
              index_col=0)
# Out:
#     男肺活量       女肺活量      男50米跑      女50米跑       男体前屈       ...  女跳远       \
#       成绩   分数    成绩   分数    成绩   分数    成绩   分数    成绩   分数  ...   成绩   分数
# 0   4540  100  3150  100   7.1  100   7.8  100  23.6  100  ...  204  100
# 1   4420   95  3100   95   7.2   95   7.9   95  21.5   95  ...  198   95
# 2   4300   90  3050   90   7.3   90   8.0   90  19.4   90  ...  192   90
# 3   4050   85  2900   85   7.4   85   8.3   85  17.2   85  ...  185   85
# 4   3800   80  2750   80   7.5   80   8.6   80  15.0   80  ...  178   80
# 5   3680   78  2650   78   7.7   78   8.8   78  13.6   78  ...  175   78
# 6   3560   76  2550   76   7.9   76   9.0   76  12.2   76  ...  172   76
# 7   3440   74  2450   74   8.1   74   9.2   74  10.8   74  ...  169   74
# 8   3320   72  2350   72   8.3   72   9.4   72   9.4   72  ...  166   72
# 9   3200   70  2250   70   8.5   70   9.6   70   8.0   70  ...  163   70
# 10  3080   68  2150   68   8.7   68   9.8   68   6.6   68  ...  160   68
# ...

# %%
score.to_csv('./项目实战一（体测数据处理）/体侧成绩评分表_处理.csv',index = False)

# %%
pd.read_csv('./项目实战一（体测数据处理）/体侧成绩评分表_处理.csv',header=[0,1])
# Out:
#     男肺活量       女肺活量      男50米跑      女50米跑       男体前屈       ...  女跳远       \
#       成绩   分数    成绩   分数    成绩   分数    成绩   分数    成绩   分数  ...   成绩   分数
# 0   4540  100  3150  100   7.1  100   7.8  100  23.6  100  ...  204  100
# 1   4420   95  3100   95   7.2   95   7.9   95  21.5   95  ...  198   95
# 2   4300   90  3050   90   7.3   90   8.0   90  19.4   90  ...  192   90
# 3   4050   85  2900   85   7.4   85   8.3   85  17.2   85  ...  185   85
# 4   3800   80  2750   80   7.5   80   8.6   80  15.0   80  ...  178   80
# 5   3680   78  2650   78   7.7   78   8.8   78  13.6   78  ...  175   78
# 6   3560   76  2550   76   7.9   76   9.0   76  12.2   76  ...  172   76
# 7   3440   74  2450   74   8.1   74   9.2   74  10.8   74  ...  169   74
# 8   3320   72  2350   72   8.3   72   9.4   72   9.4   72  ...  166   72
# 9   3200   70  2250   70   8.5   70   9.6   70   8.0   70  ...  163   70
# 10  3080   68  2150   68   8.7   68   9.8   68   6.6   68  ...  160   68
# ...

# %% [markdown]
# ## <font color='red'>男1000米跑成绩分数转换？（项目实战）</font>

# %%
# %%time
import pandas as pd
# 加载处理之后的男生体测成绩
df_boy = pd.read_excel('./项目实战一（体测数据处理）/体测成绩_男.xlsx')
# 加载成绩评分表
score = pd.read_excel('./项目实战一（体测数据处理）/体侧成绩评分表_处理.xlsx', header = [0,1],index_col=0)
display(df_boy,score)
# Out:
#      性别     姓名  男1000米跑  男50米跑  男跳远  男体前屈  男引体  男肺活量
# 0     男  郭*森18     5.19   9.55  210    15    6  7042
# 1     男  苏*飞27     4.12   8.60  215    15   11  3458
# 2     男  寻*潇13     4.17   8.16  215    14    4  4336
# 3     男  郭*冉36     4.19   8.96  205    14    0  4539
# 4     男  王*磊40     0.00   8.30  230    14    9  6059
# ...  ..    ...      ...    ...  ...   ...  ...   ...
# 1080  男   闫*轩1     4.04   8.13  210     1    7  5012
# 1081  男   王*飞2     3.49   7.62  203    11   12  4138
# 1082  男   赵*龙1     5.02   9.50  200    14    5  1437
# 1083  男  毕*谦28     4.26   8.52  210    18    9  4814
# 1084  男  李*阳19     4.20   8.21  219     6   10  4469
#
# [1085 rows x 8 columns]
#     男肺活量       女肺活量      男50米跑      女50米跑       男体前屈       ...  女跳远       \
#       成绩   分数    成绩   分数    成绩   分数    成绩   分数    成绩   分数  ...   成绩   分数
# 0   4540  100  3150  100   7.1  100   7.8  100  23.6  100  ...  204  100
# 1   4420   95  3100   95   7.2   95   7.9   95  21.5   95  ...  198   95
# ...

# %%
# %%time
# 定义转换方法
def convert(x):
    if x == 0: # 说明没有参加体能测试，分数为0分
        return 0
    for i in range(20): # 成绩划分20等级
        if x <= score['男1000米跑']['成绩'][i]:
            return score['男1000米跑']['分数'][i]
    return 0 # 说明跑的太慢了，分数为0分
result = df_boy['男1000米跑'].apply(convert)
df_boy.insert(3,column='男1000米跑分数',value= result)
df_boy
# Out:
# CPU times: total: 6.27 s
# Wall time: 6.39 s
#      性别     姓名  男1000米跑  男1000米跑分数  男50米跑  男跳远  男体前屈  男引体  男肺活量
# 0     男  郭*森18     5.19         40   9.55  210    15    6  7042
# 1     男  苏*飞27     4.12         72   8.60  215    15   11  3458
# 2     男  寻*潇13     4.17         70   8.16  215    14    4  4336
# 3     男  郭*冉36     4.19         70   8.96  205    14    0  4539
# 4     男  王*磊40     0.00          0   8.30  230    14    9  6059
# ...  ..    ...      ...        ...    ...  ...   ...  ...   ...
# 1080  男   闫*轩1     4.04         76   8.13  210     1    7  5012
# 1081  男   王*飞2     3.49         80   7.62  203    11   12  4138
# 1082  男   赵*龙1     5.02         50   9.50  200    14    5  1437
# 1083  男  毕*谦28     4.26         66   8.52  210    18    9  4814
# 1084  男  李*阳19     4.20         70   8.21  219     6   10  4469
#
# [1085 rows x 9 columns]

# %% [markdown]
# ## <font color='red'>速度型成绩分数批量转换？（项目实战）</font>

# %%
# %%time
import numpy as np
import pandas as pd
df_boy = pd.read_excel('./项目实战一（体测数据处理）/体测成绩_男.xlsx')
score = pd.read_excel('./项目实战一（体测数据处理）/体侧成绩评分表_处理.xlsx', header = [0,1],index_col=0)
display(df_boy,score)
cols = ['男1000米跑', '男50米跑']
def convert(x, col):
    if x == 0: # 说明没有参加体能测试，分数为0分
        return 0
    for i in range(20): # 成绩划分20等级
        if x <= score[col]['成绩'][i]:
            return score[col]['分数'][i]
    return 0 # 说明跑的太慢了，分数为0分
for col in cols:
    # args 传入的参数 (col,)
    s = df_boy[col].apply(convert, args = (col,))
    columns = df_boy.columns.to_list()
    index = columns.index(col) + 1 # 这一列后面
    # 向这一列后面添加一列：分数
    df_boy.insert(loc = index, column = col + '分数', value = s)
df_boy.head(20)
# Out:
#      性别     姓名  男1000米跑  男50米跑  男跳远  男体前屈  男引体  男肺活量
# 0     男  郭*森18     5.19   9.55  210    15    6  7042
# 1     男  苏*飞27     4.12   8.60  215    15   11  3458
# 2     男  寻*潇13     4.17   8.16  215    14    4  4336
# 3     男  郭*冉36     4.19   8.96  205    14    0  4539
# 4     男  王*磊40     0.00   8.30  230    14    9  6059
# ...  ..    ...      ...    ...  ...   ...  ...   ...
# 1080  男   闫*轩1     4.04   8.13  210     1    7  5012
# 1081  男   王*飞2     3.49   7.62  203    11   12  4138
# 1082  男   赵*龙1     5.02   9.50  200    14    5  1437
# 1083  男  毕*谦28     4.26   8.52  210    18    9  4814
# 1084  男  李*阳19     4.20   8.21  219     6   10  4469
#
# [1085 rows x 8 columns]
#     男肺活量       女肺活量      男50米跑      女50米跑       男体前屈       ...  女跳远       \
#       成绩   分数    成绩   分数    成绩   分数    成绩   分数    成绩   分数  ...   成绩   分数
# 0   4540  100  3150  100   7.1  100   7.8  100  23.6  100  ...  204  100
# 1   4420   95  3100   95   7.2   95   7.9   95  21.5   95  ...  198   95
# ...

# %%
pd.Series.apply()

# %% [markdown]
# ## <font color='red'>力量型成绩分数批量转换？（项目实战）</font>

# %%
# %%time
# convert自定义，名字任意
def convert(x, col):
    for i in range(20): # 成绩划分20等级
        if x >= score[col]['成绩'][i]:
            return score[col]['分数'][i]
    return 0 # 说明跳远不达标，分数为0分

cols = ['男跳远', '男体前屈','男引体', '男肺活量']
for col in cols:
    # apply ,args = (col,)代表某一列，成绩分数转换
    s = df_boy[col].apply(convert, args = (col,))
    columns = df_boy.columns.to_list()
    # 后面插入一列
    index = columns.index(col) + 1
    df_boy.insert(loc = index, column = col + '分数', value = s)
df_boy.head()
# Out:
# CPU times: total: 22.2 s
# Wall time: 22.3 s
#   性别     姓名  男1000米跑  男1000米跑分数  男50米跑  男50米跑分数  男跳远  男跳远分数  男体前屈  男体前屈分数  \
# 0  男  郭*森18     5.19         40   9.55       50  210     66    15      80
# 1  男  苏*飞27     4.12         72   8.60       68  215     70    15      80
# 2  男  寻*潇13     4.17         70   8.16       72  215     70    14      78
# 3  男  郭*冉36     4.19         70   8.96       64  205     64    14      78
# 4  男  王*磊40     0.00          0   8.30       72  230     76    14      78
#
#    男引体  男引体分数  男肺活量  男肺活量分数
# 0    6     50  7042     100
# 1   11     76  3458      74
# 2    4     30  4336      90
# 3    0      0  4539      95
# 4    9     68  6059     100

# %%
df_boy.head(20)
# Out:
#    性别     姓名  男1000米跑  男1000米跑分数  男50米跑  男50米跑分数  男跳远  男跳远分数  男体前屈  男体前屈分数  \
# 0   男  郭*森18     5.19         40   9.55       50  210     66    15      80
# 1   男  苏*飞27     4.12         72   8.60       68  215     70    15      80
# 2   男  寻*潇13     4.17         70   8.16       72  215     70    14      78
# 3   男  郭*冉36     4.19         70   8.96       64  205     64    14      78
# 4   男  王*磊40     0.00          0   8.30       72  230     76    14      78
# 5   男  闫*意15     3.21        100   7.16       95  242     80     9      70
# 6   男  麻*阳32     3.57         78   8.40       70  196     60    14      78
# 7   男  刘*雄28     3.53         80   7.88       76  230     76     9      70
# 8   男   贾*博7     4.17         70   8.23       72  230     76    14      78
# 9   男  刘*硕33     3.49         80   7.94       74  190     50    20      90
# 10  男  高*阳32     4.13         72   8.88       66  195     60    12      74
# ...

# %%
score['男肺活量']
# Out:
#       成绩   分数
# 0   4540  100
# 1   4420   95
# 2   4300   90
# 3   4050   85
# 4   3800   80
# 5   3680   78
# 6   3560   76
# 7   3440   74
# 8   3320   72
# 9   3200   70
# 10  3080   68
# 11  2960   66
# 12  2840   64
# 13  2720   62
# 14  2600   60
# 15  2470   50
# 16  2340   40
# 17  2210   30
# 18  2080   20
# 19  1950   10

# %% [markdown]
# ## <font color='red'>全部数据处理转换与保存？（项目实战）</font>

# %% [markdown]
# ### 女生速度型

# %%
# %%time
import numpy as np
import pandas as pd
df_girl = pd.read_excel('./项目实战一（体测数据处理）/体测成绩_女.xlsx')
score = pd.read_excel('./项目实战一（体测数据处理）/体侧成绩评分表_处理.xlsx', header = [0,1],index_col=0)
display(df_girl,score)
cols = ['女800米跑', '女50米跑']
def convert(x, col):
    if x == 0: # 说明没有参加体能测试，分数为0分
        return 0
    for i in range(20): # 成绩划分20等级
        if x <= score[col]['成绩'][i]:
            return score[col]['分数'][i]
    return 0 # 说明跑的太慢了，分数为0分
for col in cols:
    # args 传入的参数 (col,)
    s = df_girl[col].apply(convert, args = (col,))
    columns = df_girl.columns.to_list()
    index = columns.index(col) + 1 # 这一列后面
    # 向这一列后面添加一列：分数
    df_girl.insert(loc = index, column = col + '分数', value = s)
df_girl.head(20)
# Out:
#      性别     姓名  女800米跑  女50米跑  女跳远  女体前屈  女仰卧  女肺活量
# 0     女   李*帆6    4.00   9.92  172    23   40  2348
# 1     女  吕*璇40    3.55  10.94  160    14   39  2588
# 2     女  任*哲30    3.29   8.79  150    17   36  3043
# 3     女  李*琦13    3.36  10.16  167    13   41  3276
# 4     女  高*润32    3.49   9.99  160    10   40  2410
# ...  ..    ...     ...    ...  ...   ...  ...   ...
# 1069  女  贾*华35    3.52   9.84  178    18   40  2350
# 1070  女  井*欣15    4.08   9.80  165    15   40  4086
# 1071  女  王*辉28    3.58   9.60  160    30   40  3059
# 1072  女  陈*怡30    3.32  10.08  152    19   39  2982
# 1073  女  麻*蕾29    3.45   9.05  152    18   40  3122
#
# [1074 rows x 8 columns]
#     男肺活量       女肺活量      男50米跑      女50米跑       男体前屈       ...  女跳远       \
#       成绩   分数    成绩   分数    成绩   分数    成绩   分数    成绩   分数  ...   成绩   分数
# 0   4540  100  3150  100   7.1  100   7.8  100  23.6  100  ...  204  100
# 1   4420   95  3100   95   7.2   95   7.9   95  21.5   95  ...  198   95
# ...

# %% [markdown]
# ### 女生力量型

# %%
# %%time
# convert自定义，名字任意
def convert(x, col):
    for i in range(20): # 成绩划分20等级
        if x >= score[col]['成绩'][i]:
            return score[col]['分数'][i]
    return 0 # 说明跳远不达标，分数为0分

cols = ['女跳远', '女体前屈','女仰卧', '女肺活量']
for col in cols:
    # apply ,args = (col,)代表某一列，成绩分数转换
    s = df_girl[col].apply(convert, args = (col,))
    columns = df_girl.columns.to_list()
    # 后面插入一列
    index = columns.index(col) + 1
    df_girl.insert(loc = index, column = col + '分数', value = s)
df_girl.head()
# Out:
# CPU times: total: 19.7 s
# Wall time: 19.8 s
#   性别     姓名  女800米跑  女800米跑分数  女50米跑  女50米跑分数  女跳远  女跳远分数  女体前屈  女体前屈分数  女仰卧  \
# 0  女   李*帆6    4.00        76   9.92       66  172     76    23      95   40
# 1  女  吕*璇40    3.55        78  10.94       40  160     68    14      74   39
# 2  女  任*哲30    3.29        95   8.79       78  150     60    17      78   36
# 3  女  李*琦13    3.36        90  10.16       64  167     72    13      72   41
# 4  女  高*润32    3.49        80   9.99       66  160     68    10      68   40
#
#    女仰卧分数  女肺活量  女肺活量分数
# 0     76  2348      70
# 1     76  2588      76
# 2     72  3043      85
# 3     78  3276     100
# 4     76  2410      72

# %% [markdown]
# ### 男女数据写入一个表

# %%
with pd.ExcelWriter('./项目实战一（体测数据处理）/所有数据.xlsx') as writer:
    df_boy.to_excel(writer,index = False,sheet_name = '男生')
    df_girl.to_excel(writer,index = False,sheet_name = '女生')
    score.to_excel(writer,header=[0,1],sheet_name = '评分标准')

# %% [markdown]
# ## <font color='red'>薪资区间转为平均薪资？（项目实战二招聘数据处理）</font>

# %%
import pandas as pd
job = pd.read_csv('./项目实战二（招聘数据处理）/job.csv',encoding='gbk')
job
# Out:
#        positionName companyShortName city companySize education financeStage  \
# 0           高级数据分析师              拉勾网   北京   500-2000人        本科        D轮及以上
# 1             数据分析师         OK Group   北京   500-2000人        大专           B轮
# 2           高级数据分析师           金山办公软件   北京     2000人以上        本科         上市公司
# 3             数据分析师           金山办公软件   北京     2000人以上        本科         上市公司
# 4             数据分析师             京东集团   北京     2000人以上        本科         上市公司
# ...             ...              ...  ...         ...       ...          ...
# 3678  内容运营高级经理-审核方向             字节跳动   天津     2000人以上        本科           C轮
# 3679      质检岗位基层管理岗             字节跳动   天津     2000人以上        本科           C轮
# 3680         高级审核编辑             字节跳动   天津     2000人以上        本科           C轮
# 3681       数据运营分析专员             字节跳动   天津     2000人以上        本科           C轮
# 3682      数据运营分析实习生             字节跳动   天津     2000人以上        本科           C轮
#
#      industryField   salary workYear
# ...

# %%
job['positionName'].value_counts()[:20]
# Out:
# 数据分析师      549
# 高级数据分析师    100
# 产品经理        87
# 数据分析        69
# 数据分析专员      42
# 数据分析实习生     34
# 数据分析专家      33
# 新媒体运营       32
# 电商运营        30
# 资深数据分析师     29
# 数据分析工程师     29
# 大数据分析师      23
# 运营专员        20
# 游戏数据分析师     18
# 产品运营        18
# 数据分析经理      18
# 销售经理        16
# 商业数据分析师     16
# 高级产品经理      15
# 数据分析助理      13
# Name: positionName, dtype: int64

# %%
cond = job["positionName"].str.contains("数据|分析|BI|bi")
job2 = job[cond]
job2
# Out:
#      positionName companyShortName city companySize education financeStage  \
# 0         高级数据分析师              拉勾网   北京   500-2000人        本科        D轮及以上
# 1           数据分析师         OK Group   北京   500-2000人        大专           B轮
# 2         高级数据分析师           金山办公软件   北京     2000人以上        本科         上市公司
# 3           数据分析师           金山办公软件   北京     2000人以上        本科         上市公司
# 4           数据分析师             京东集团   北京     2000人以上        本科         上市公司
# ...           ...              ...  ...         ...       ...          ...
# 3601       数据产品经理             北京天宇   天津   500-2000人        本科          未融资
# 3629      需求分析工程师             易景环境   天津   500-2000人        大专         上市公司
# 3674    数据中心项目负责人             字节跳动   天津     2000人以上        本科           C轮
# 3681     数据运营分析专员             字节跳动   天津     2000人以上        本科           C轮
# 3682    数据运营分析实习生             字节跳动   天津     2000人以上        本科           C轮
#
#      industryField   salary workYear
# ...

# %%
job[~cond]
# Out:
#                positionName companyShortName city companySize education  \
# 1740          物流运营/商户运营（南京）             达达集团   南京     2000人以上        大专
# 1742                新媒体运营主管             景枫集团   南京   500-2000人        本科
# 1747                  运营实习生              河狸家   南京   500-2000人        本科
# 1748  项目执行/客户执行/媒介执行/广告执行AE             蔚蓝云创   南京    150-500人        大专
# 1749                   产品经理              聚目堂   南京     50-150人        本科
# ...                     ...              ...  ...         ...       ...
# 3676               资深模型优化专员             字节跳动   天津     2000人以上        本科
# 3677               内容质量高级经理             字节跳动   天津     2000人以上        本科
# 3678          内容运营高级经理-审核方向             字节跳动   天津     2000人以上        本科
# 3679              质检岗位基层管理岗             字节跳动   天津     2000人以上        本科
# 3680                 高级审核编辑             字节跳动   天津     2000人以上        本科
#
#      financeStage industryField   salary workYear
# 1740         上市公司          消费生活   6k-10k     3-5年
# ...

# %%
cond = job2['salary'].str.contains('K')
job2[cond]
# Out:
#     positionName companyShortName city companySize education financeStage  \
# 387        数据分析师             一览科技   北京    150-500人        本科           B轮
#
#     industryField   salary workYear
# 387   移动互联网,文娱丨内容  20K-40K     1-3年

# %%
# 处理过程
# 1、将salary中的字符串均小写化（因为存在20K-40K，大写情况）
# 2、运用正则表达式提取出薪资区间
# 3、将提取出来的数字转化为int型
# 4、取区间的平均值
job2["salary"].str.lower().str.extract(r'(\d+)k-(\d+)k').applymap(lambda x : int(x))
# Out:
#        0   1
# 0     25  35
# 1     25  45
# 2     15  25
# 3     15  25
# 4     15  30
# ...   ..  ..
# 3601   5  10
# 3629   7  14
# 3674   6  10
# 3681   6   8
# 3682   2   3
#
# [1989 rows x 2 columns]

# %%
result = job2["salary"].str.lower().str.extract(r'(\d+)k-(\d+)k').astype('int64').mean(axis = 1)
job2.insert(8,column = '平均薪资',value = result)
job2
# Out:
#      positionName companyShortName city companySize education financeStage  \
# 0         高级数据分析师              拉勾网   北京   500-2000人        本科        D轮及以上
# 1           数据分析师         OK Group   北京   500-2000人        大专           B轮
# 2         高级数据分析师           金山办公软件   北京     2000人以上        本科         上市公司
# 3           数据分析师           金山办公软件   北京     2000人以上        本科         上市公司
# 4           数据分析师             京东集团   北京     2000人以上        本科         上市公司
# ...           ...              ...  ...         ...       ...          ...
# 3601       数据产品经理             北京天宇   天津   500-2000人        本科          未融资
# 3629      需求分析工程师             易景环境   天津   500-2000人        大专         上市公司
# 3674    数据中心项目负责人             字节跳动   天津     2000人以上        本科           C轮
# 3681     数据运营分析专员             字节跳动   天津     2000人以上        本科           C轮
# 3682    数据运营分析实习生             字节跳动   天津     2000人以上        本科           C轮
#
#      industryField   salary  平均薪资 workYear
# ...

# %%
job2.to_csv('./项目实战二（招聘数据处理）/数据分析岗位.csv',index=False)

# %% [markdown]
# ## <font color='red'>不同城市对数据分析的需求量？（项目实战二招聘数据处理）</font>

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams['font.family'] = 'STKaiti'

job = pd.read_csv('./项目实战二（招聘数据处理）/数据分析岗位.csv')
display(job)
cities = job['city'].value_counts() # 统计城市工作数量
cities # 降序
# Out:
#      positionName companyShortName city companySize education financeStage  \
# 0         高级数据分析师              拉勾网   北京   500-2000人        本科        D轮及以上
# 1           数据分析师         OK Group   北京   500-2000人        大专           B轮
# 2         高级数据分析师           金山办公软件   北京     2000人以上        本科         上市公司
# 3           数据分析师           金山办公软件   北京     2000人以上        本科         上市公司
# 4           数据分析师             京东集团   北京     2000人以上        本科         上市公司
# ...           ...              ...  ...         ...       ...          ...
# 1984       数据产品经理             北京天宇   天津   500-2000人        本科          未融资
# 1985      需求分析工程师             易景环境   天津   500-2000人        大专         上市公司
# 1986    数据中心项目负责人             字节跳动   天津     2000人以上        本科           C轮
# 1987     数据运营分析专员             字节跳动   天津     2000人以上        本科           C轮
# 1988    数据运营分析实习生             字节跳动   天津     2000人以上        本科           C轮
#
#      industryField   salary  平均薪资 workYear
# ...

# %%
plt.figure(figsize=(12,9))
plt.barh(y = cities.index[::-1],
        width = cities.values[::-1],
        color = '#3c7f99')
plt.box(False) # 不显示边框

plt.title(label='           各城市数据分析岗位的需求量           ', 
          fontsize=32, weight='bold', color='white', 
          backgroundcolor='#c5b783',pad = 30 )

plt.tick_params(labelsize = 16)
plt.grid(axis = 'x',linewidth = 0.5,color = '#3c7f99')

# %%
from matplotlib.font_manager import FontManager
fm = FontManager()
[font.name for font in fm.ttflist]
# Out:
# ['DejaVu Serif',
#  'STIXNonUnicode',
#  'cmss10',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'STIXSizeOneSym',
#  'STIXSizeFiveSym',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'cmtt10',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'cmr10',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'cmex10',
#  'DejaVu Serif',
#  'cmsy10',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Display',
#  'DejaVu Serif',
#  'DejaVu Serif Display',
#  'DejaVu Sans Mono',
#  'STIXSizeThreeSym',
#  'cmb10',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'cmmi10',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'KaiTi',
#  'Tw Cen MT Condensed',
#  'Kunstler Script',
#  'Goudy Old Style',
#  'Microsoft JhengHei',
#  'Palace Script MT',
#  'Californian FB',
#  'Bernard MT Condensed',
#  'SimSun-ExtB',
#  'Segoe UI',
#  'Malgun Gothic',
#  'Arial Rounded MT Bold',
# ...

# %% [markdown]
# ## <font color='red'>不同领域对数据分析的需求量？（项目实战二招聘数据处理）</font>

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams['font.family'] = 'STKaiti'
job = pd.read_csv('./项目实战二（招聘数据处理）/数据分析岗位.csv')
job["industryField"].value_counts()[:30]
# Out:
# 金融             161
# 移动互联网          141
# 文娱丨内容          111
# 电商              92
# 数据服务            83
# 移动互联网,电商        76
# 移动互联网,数据服务      61
# 移动互联网,金融        58
# 社交              57
# 企业服务            53
# 消费生活            51
# 移动互联网,教育        50
# 移动互联网,游戏        47
# 移动互联网,消费生活      46
# 游戏              38
# 电商,移动互联网        37
# 移动互联网,文娱丨内容     35
# 移动互联网,社交        35
# 教育              35
# 其他              32
# 汽车丨出行           31
# 企业服务,数据服务       24
# 移动互联网,硬件        24
# 数据服务,移动互联网      23
# 电商,消费生活         20
# 硬件              19
# 移动互联网,企业服务      19
# 金融,软件开发         18
# 数据服务,广告营销       17
# 信息安全,数据服务       16
# Name: industryField, dtype: int64

# %%
def clean_industry(industry):
    industry = industry.split(",")
    if industry[0]=="移动互联网" and len(industry)>1:
        return industry[1]
    else:
        return industry[0]
    
job["industryField"] = job.industryField.map(clean_industry)
job
# Out:
#      positionName companyShortName city companySize education financeStage  \
# 0         高级数据分析师              拉勾网   北京   500-2000人        本科        D轮及以上
# 1           数据分析师         OK Group   北京   500-2000人        大专           B轮
# 2         高级数据分析师           金山办公软件   北京     2000人以上        本科         上市公司
# 3           数据分析师           金山办公软件   北京     2000人以上        本科         上市公司
# 4           数据分析师             京东集团   北京     2000人以上        本科         上市公司
# ...           ...              ...  ...         ...       ...          ...
# 1984       数据产品经理             北京天宇   天津   500-2000人        本科          未融资
# 1985      需求分析工程师             易景环境   天津   500-2000人        大专         上市公司
# 1986    数据中心项目负责人             字节跳动   天津     2000人以上        本科           C轮
# 1987     数据运营分析专员             字节跳动   天津     2000人以上        本科           C轮
# 1988    数据运营分析实习生             字节跳动   天津     2000人以上        本科           C轮
#
#      industryField   salary  平均薪资 workYear
# ...

# %%
job.industryField.value_counts()[:30]
# Out:
# 电商            271
# 金融            271
# 数据服务          249
# 文娱丨内容         149
# 企业服务          145
# 移动互联网         141
# 消费生活          114
# 社交            103
# 游戏             96
# 教育             94
# 硬件             56
# 其他             46
# 医疗丨健康          34
# 汽车丨出行          33
# 信息安全           32
# 广告营销           28
# 人工智能           23
# 房产家居           18
# 软件开发           12
# 物流丨运输          11
# 旅游             10
# 通讯电子            8
# 工具              8
# 物联网             5
# 数据服务、教育         5
# 电子商务            4
# 医疗健康            3
# 电子商务 移动互联网      3
# 区块链             2
# 金融 广告营销         2
# Name: industryField, dtype: int64

# %%
# 获取需求量前10多的领域
industry_index = job["industryField"].value_counts()[:10].index
industry_index
# Out:
# Index(['电商', '金融', '数据服务', '文娱丨内容', '企业服务', '移动互联网', '消费生活', '社交', '游戏', '教育'], dtype='object')

# %%
# 数据筛选
industry =job.loc[job["industryField"].isin(industry_index),"industryField"]
industry
# Out:
# 0        企业服务
# 1          金融
# 2       移动互联网
# 3       移动互联网
# 4          电商
#         ...
# 1984     企业服务
# 1985     企业服务
# 1986    文娱丨内容
# 1987    文娱丨内容
# 1988    文娱丨内容
# Name: industryField, Length: 1633, dtype: object

# %%
plt.figure(figsize=(12,9))
plt.barh(y = industry_index[::-1],
         width=pd.Series.value_counts(industry.values).values[::-1],
         color = '#3c7f99')
plt.title(label='      不同领域数据分析岗位的需求量（取前十）     ', 
          fontsize=32, weight='bold', color='white', 
          backgroundcolor='#c5b783',ha = 'center',pad = 30)
plt.tick_params(labelsize=16)
plt.grid(lw = 0.5,color = '#3c7f99',ls = '--')

# %%
data = job["industryField"].value_counts()[:10]
plt.figure(figsize=(12,9))
plt.barh(y = data.index[::-1],
         width=data.values[::-1],
         color = '#3c7f99')
plt.title(label='      不同领域数据分析岗位的需求量（取前十）     ', 
          fontsize=32, weight='bold', color='white', 
          backgroundcolor='#c5b783',ha = 'center',pad = 30)
plt.tick_params(labelsize=16)
plt.grid(lw = 0.5,color = '#3c7f99',ls = '--')

# %% [markdown]
# ## <font color='red'>不同城市数据分析薪资情况？（项目实战二招聘数据处理）</font>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
job = pd.read_csv('./项目实战二（招聘数据处理）/数据分析岗位.csv')
job
# Out:
#      positionName companyShortName city companySize education financeStage  \
# 0         高级数据分析师              拉勾网   北京   500-2000人        本科        D轮及以上
# 1           数据分析师         OK Group   北京   500-2000人        大专           B轮
# 2         高级数据分析师           金山办公软件   北京     2000人以上        本科         上市公司
# 3           数据分析师           金山办公软件   北京     2000人以上        本科         上市公司
# 4           数据分析师             京东集团   北京     2000人以上        本科         上市公司
# ...           ...              ...  ...         ...       ...          ...
# 1984       数据产品经理             北京天宇   天津   500-2000人        本科          未融资
# 1985      需求分析工程师             易景环境   天津   500-2000人        大专         上市公司
# 1986    数据中心项目负责人             字节跳动   天津     2000人以上        本科           C轮
# 1987     数据运营分析专员             字节跳动   天津     2000人以上        本科           C轮
# 1988    数据运营分析实习生             字节跳动   天津     2000人以上        本科           C轮
#
#      industryField   salary  平均薪资 workYear
# ...

# %%
city_mean_salary = job.groupby("city")["平均薪资"].mean().sort_values() # 分组聚合运算
city_mean_salary
# Out:
# city
# 天津     8.450000
# 西安    11.551724
# 成都    12.049550
# 长沙    12.236842
# 广州    15.246575
# 武汉    15.903226
# 苏州    16.148148
# 南京    16.698529
# 厦门    18.312500
# 深圳    20.431129
# 上海    20.462704
# 杭州    21.209790
# 北京    21.432222
# Name: 平均薪资, dtype: float64

# %%
plt.figure(figsize=(12,9))
plt.bar(x = city_salary.index,height = city_salary.values,
       color = plt.cm.GnBu(np.linspace(0,1,len(city_salary))))

plt.title(label='              各城市的薪资水平对比              ', 
         fontsize=32, weight='bold', color='white', backgroundcolor='#3c7f99')
plt.tick_params(labelsize=16)
plt.grid(axis = 'y',linewidth = 0.5,color = 'black')
plt.yticks(ticks = np.arange(0,25,step = 5,),labels = ['','5k','10k','15k','20k'])
plt.box(False) # 去掉边框
